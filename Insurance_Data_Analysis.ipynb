# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("insurance.csv")
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %% [markdown]
# Here, firstly imported numpy,pandas,matplotlib,seaborn (useful libraries)
# After, that the data is got imported from insurance.csv file

# %%
# checking shape of the data
df.shape
# Out:
# (1338, 7)

# %% [markdown]
# Shape of the data is 1338 rows and 7 columns.

# %%
# checking data types of the columns and summary of the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
# There are 3 categorical columns:
#sex
#smoker
#region

# %% [markdown]
# So,here 7 columns are present and their data types :
# 2 columns consists floating values,
# 2 columns consists integer values and
# 3 columns are object/strings values in nature.

# %%
# checking null values
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %% [markdown]
# Here, there are no such null values (empty or missing data) in whole dataset

# %%
# statistical summary for numerical columns
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
# statistical summary for non-numerical columns
df.describe(include = "object")
# Out:
#          sex smoker     region
# count   1338   1338       1338
# unique     2      2          4
# top     male     no  southeast
# freq     676   1064        364

# %% [markdown]
# # Relation Between Feature Columns and Targeted Columns

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
# check no.of categories in sex column

plt.figure(figsize = (4,5))
sns.countplot(x = "sex",data = df,color = "c")
plt.title("Count of Genders")
plt.show()

# %%
# overll summary in sex column
df["sex"].value_counts()
# Out:
# sex
# male      676
# female    662
# Name: count, dtype: int64

# %% [markdown]
# Count of both genders in sex column: Total 676 males and 662 females.

# %%
# check no.of categories in smoker column

plt.figure(figsize = (4,5))
sns.countplot(x = "smoker",data = df,color = "red")
plt.title("Count of Smokers")
plt.show()

# %%
# overall summary in smoker column
df["smoker"].value_counts()
# Out:
# smoker
# no     1064
# yes     274
# Name: count, dtype: int64

# %% [markdown]
# Count of both smoker and non-smoker in smoker column: Total 1064 non-smoker and 274 smoker.

# %%
# check no.of categories in region column

plt.figure(figsize = (7,5))
sns.countplot(x = "region",data = df,hue = "region")
plt.title("Count of Regions")
plt.show()

# %%
# overall summary of region column
df["region"].value_counts()
# Out:
# region
# southeast    364
# southwest    325
# northwest    325
# northeast    324
# Name: count, dtype: int64

# %% [markdown]
# Count of all the regions mention in region column: In southeast region 364 records ,
# southwest region 325 records, northwest region 325 records and northeast region 324 records are present

# %%
# checking relation between age vs charges

sns.scatterplot(x = "age",y = "charges",data = df)
plt.title("age VS charges")
plt.show()

# %% [markdown]
# From above scatter plot of age and charges, it clearly shows by the age is getting increases the charges of insurance premium is also timely increases. So, that's partial positive relation between both the variables.

# %%
# checking relation between bmi vs charges

sns.scatterplot(x = "bmi",y = "charges",data = df)
plt.title("BMI vs Charges")
plt.show()

# %% [markdown]
# From above scatter plot of BMI and Charges, it clearly shows there are not such relation between them.
# But the charges above 40,000 and age is more than 30 has higher charges possibly they are smokers or other factor is responsible. Otherwise there is no relation between BMI and Charges.

# %%
# checking relation between children vs charges

sns.scatterplot(x = "children",y = "charges",data = df)
plt.title("children VS charges")
plt.show()

# %% [markdown]
# From above scatter plot of children and charges, it clearly shows there are not such relation between them.

# %% [markdown]
# # Perform Data Visualization Using Plots of Feature vs Feature

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %% [markdown]
# ##  **Numerical v/s Numerical**

# %%
# (1) relation b/w "age" vs "bmi"

sns.jointplot(x = "age",y = "bmi",data = df,kind = "hex")
plt.show()

# %% [markdown]
# From above jointplot shows the normal BMI criteria is ~22 to ~48. All the age group of people are most in these range.Hence,most common age group are <25 maximum number of people lies in this range with normal BMI.

# %%
# (2) finding and plotting correlation between all the numerical columns 

corr_mat = df.corr(numeric_only = True)
plt.figure(figsize = (10,5))
sns.heatmap(corr_mat, linewidths = 0.5,annot = True,fmt = ".1f")
plt.title("correlation for numerical data")
plt.show()

# %% [markdown]
# As per the correlation heatmap, Whose score < 0.2 are considered as weak relation and rest of all are quite good relation compare to them.

# %%
# (3) finding relation between all two numerical columns with each other separatly 

numeric_data = ["age","bmi","children","charges"]
sns.pairplot(df[numeric_data]) 
plt.show()

# %% [markdown]
# Here,in above pairplot shows each numerical relation between all the numerical columns.
# 1) partial positive relation between columns : age vs charges
# 2) no relation columns : remain almost all the columns are not correlated/no relation between them
# * So, Only one relation that are said to be partially positive and rest of all had no relation or weak relation.

# %% [markdown]
# #  **Categorical v/s Numerical**

# %%
# (1) finding relation in between of region and their charges how they differ?

plt.figure(figsize = (10,8))
sns.boxplot(x = "region",y = "charges", data = df, hue = "region")
plt.title("Region vs Charges")
plt.show()

# %% [markdown]
# In this box plot,The median price of insurance in all the region is almost equal. Here, in southeast region some of people paying higher insurance compare to all of them and maximum number of outlier is also from southeast and southwest.

# %% [markdown]
# #  **Categorical v/s Categorical**

# %%
# (1) finding relation between region and gender

cp = pd.crosstab(index = df["region"] , columns = df["sex"])
cp
# Out:
# sex        female  male
# region
# northeast     161   163
# northwest     164   161
# southeast     175   189
# southwest     162   163

# %%
cp.plot(kind = "bar",stacked = True,figsize = (8,6),cmap  = "Paired")
plt.title("Region vs Sex")
plt.legend(loc = "upper left")
plt.show()

# %% [markdown]
# From above stacked bar plot it shows the relation of region and gender, For the population of female and male is almost equal in all the region excluding southeast region. In southeast region still female population is similar as all the region, but male population is higher in this region.

# %% [markdown]
# # Check If The Number Of Premium Charges For Smokers Or Non-Smokers Is Increasing As They Are Aging?

# %%
# Checking the premium charges for smoker or non-smoker is increasing as they are aging

# %%
# figuring out the trend line for premium charges as they are aging (Generel Scenario)

plt.figure(figsize = (13,8))
sns.lineplot(x = "age", y = "charges", data = df, color = "green")
plt.title("Trend Line For The Age and Their Premium")
plt.show()

# %% [markdown]
# Line plot shows the positive trend line for age and theire premium charges are getting increase as they are aging.

# %%
# Now checking premium for smoker or non-smoker by their age

# How charges are differ from smoker or non-smoker as their age is getting increase ?

# %%
plt.figure(figsize = (8,7))
sns.scatterplot(x = "age",y = "charges",data = df,hue = "smoker")
plt.title("Premium For Smoker or Non-Smoker As They Are Aging")
plt.show()

# %% [markdown]
# From above scatter plot, It clearly tell us that the premium charges for the smoker is getting increases as they are aging and even higher premium charges with compare to non-smoker.

# %% [markdown]
# ##    **END**
